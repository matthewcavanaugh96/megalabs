# %% [markdown]
# Creating a dataset that will contain many more stocks (subject to missing days standard) but will contain only 90 days of data.
#
# All raw data is already downloaded, so this notebook will just be for cleaning.
