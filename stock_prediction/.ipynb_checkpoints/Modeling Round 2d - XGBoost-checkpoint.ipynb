# %% [markdown]
# # No GS

# %%
# %%time

# Import libraries
import os
import joblib

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

import xgboost as xgb


from sklearn.model_selection import (
    train_test_split,
    TimeSeriesSplit,
    GridSearchCV,
    cross_val_score,
    KFold
)

from sklearn.metrics import (
    mean_absolute_error,
    mean_squared_error,
    median_absolute_error,
    r2_score
)


# Load dataset
df_model = pd.read_csv(
    'transformed_daily_data/daily_data_5y_30k_features1.csv'
)

# Prepare dataset

# Ensure datetime formatting
df_model['timestamp'] = pd.to_datetime(df_model['timestamp'])

# Sort dataset
df_model = df_model.sort_values(
    ['ticker', 'timestamp']
).copy()


# Next day closing price
df_model['next_close'] = (
    df_model.groupby('ticker')['close'].shift(-1)
)

# Remove final row per ticker for which next_close does not exist
df_model = df_model[
    df_model['next_close'].notna()
].copy()


# Next close change
df_model['next_close_change'] = df_model['next_close'] - df_model['close']


# Next close change PCT - This will be the target
df_model['next_close_change_pct'] = (
    (df_model['next_close'] - df_model['close']) / df_model['close']
) * 100







# Train/test split

# Train on 2021-2024 data
train_df = df_model[
    (df_model['timestamp'] >= '2021-01-01') &
    (df_model['timestamp'] < '2025-01-01')
].copy()

# Test on 2025 data
test_df = df_model[
    (df_model['timestamp'] >= '2025-01-01') &
    (df_model['timestamp'] < '2026-01-01')
].copy()


# Select features - exclude index, target, leakage columns, and features determined ot be of low quality
exclude_cols = [
    'timestamp',
    'ticker',
    'next_close',
    'next_close_change',
    'next_close_change_pct',
    'rolling_volatility',
    'volume',
    'daily_high_vs_low_pct'
]

feature_cols = [
    col for col in df_model.columns
    if col not in exclude_cols
]


X_train = train_df[feature_cols]
y_train = train_df['next_close_change_pct']

X_test = test_df[feature_cols]
y_test = test_df['next_close_change_pct']


# Define model
model = xgb.XGBRegressor(random_state=42)

# Add GridSearch (not doing it in this initial notebook, just saving my place)


# Train model
model.fit(X_train, y_train)


# Get predictinos
y_test_pred = model.predict(X_test)


# Define evaluation metrics
mae = mean_absolute_error(y_test, y_test_pred)
mse = mean_squared_error(y_test, y_test_pred)
rmse = np.sqrt(mse)
medae = median_absolute_error(y_test, y_test_pred)
r2 = r2_score(y_test, y_test_pred)




# Create results dataframe
results_df = test_df.copy()


# Add predictions
results_df['pred_next_close_change_pct'] = (y_test_pred).round(2)

# Impute error
results_df['pred_error'] = results_df['pred_next_close_change_pct'] - results_df['next_close_change_pct']

# Absolute error
results_df['abs_pred_error'] = results_df['pred_error'].abs()

# Directionally correct
results_df['directionally_correct'] = (
    np.sign(results_df['next_close_change_pct']) ==
    np.sign(results_df['pred_next_close_change_pct'])
).astype(int)

# Save results
results_df.to_csv('models_daily_results/Round_2_XGBR_Default.csv', index=False)



# Print evaluation metrics
print("\n===== REGRESSION METRICS =====")

print(f"MAE:    {mae:.4f}")
print(f"MSE:    {mse:.4f}")
print(f"RMSE:   {rmse:.4f}")
print(f"MedAE:  {medae:.4f}")
print(f"R²:     {r2:.4f}")

print(
    f"Percent directionally correct: "
    f"{results_df['directionally_correct'].mean() * 100:.2f}%"
)
# Out:
# ===== REGRESSION METRICS =====
# MAE:    1.9077
# MSE:    10.6053
# RMSE:   3.2566
# MedAE:  1.1877
# R²:     -0.0272
# Percent directionally correct: 48.14%
# CPU times: user 6.49 s, sys: 1.01 s, total: 7.51 s
# Wall time: 5.13 s

# %% [markdown]
# # GridSearch for best RSME

# %%
# %%time

# Import libraries
import os
import joblib

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

import xgboost as xgb
from xgboost import XGBRegressor

from sklearn.model_selection import GridSearchCV



from sklearn.model_selection import (
    train_test_split,
    TimeSeriesSplit,
    GridSearchCV,
    cross_val_score,
    KFold
)

from sklearn.metrics import (
    mean_absolute_error,
    mean_squared_error,
    median_absolute_error,
    r2_score
)


# Load dataset
df_model = pd.read_csv(
    'transformed_daily_data/daily_data_5y_30k_features1.csv'
)

# Prepare dataset

# Ensure datetime formatting
df_model['timestamp'] = pd.to_datetime(df_model['timestamp'])

# Sort dataset
df_model = df_model.sort_values(
    ['ticker', 'timestamp']
).copy()


# Next day closing price
df_model['next_close'] = (
    df_model.groupby('ticker')['close'].shift(-1)
)

# Remove final row per ticker for which next_close does not exist
df_model = df_model[
    df_model['next_close'].notna()
].copy()


# Next close change
df_model['next_close_change'] = df_model['next_close'] - df_model['close']


# Next close change PCT - This will be the target
df_model['next_close_change_pct'] = (
    (df_model['next_close'] - df_model['close']) / df_model['close']
) * 100







# Train/test split

# Train on 2021-2024 data
train_df = df_model[
    (df_model['timestamp'] >= '2021-01-01') &
    (df_model['timestamp'] < '2025-01-01')
].copy()

# Test on 2025 data
test_df = df_model[
    (df_model['timestamp'] >= '2025-01-01') &
    (df_model['timestamp'] < '2026-01-01')
].copy()


# Select features - exclude index, target, leakage columns, and features determined ot be of low quality
exclude_cols = [
    'timestamp',
    'ticker',
    'next_close',
    'next_close_change',
    'next_close_change_pct',
    'rolling_volatility',
    'volume',
    'daily_high_vs_low_pct'
]


feature_cols = [
    col for col in df_model.columns
    if col not in exclude_cols
]


X_train = train_df[feature_cols]
y_train = train_df['next_close_change_pct']

X_test = test_df[feature_cols]
y_test = test_df['next_close_change_pct']


# Define model
model = xgb.XGBRegressor(random_state=42)

# GridSearch

# #xgbr = XGBRegressor(
#     objective="reg:squarederror",
#     random_state=42,
#     n_jobs=-1
# )


# GridSearchCV(
#     model,
#     param_grid,
#     scoring=direction_scorer,
#     cv=tscv
# )


param_grid = {
    "n_estimators": [200, 500],
    "max_depth": [3, 5],
    "learning_rate": [0.03, 0.05, 0.1],
    "subsample": [0.8, 1.0],
    "colsample_bytree": [0.8, 1.0],
    "min_child_weight": [1, 5],
    "reg_lambda": [1, 5]
}


# GridSearchCV(
#     model,
#     param_grid,
#     scoring='neg_root_mean_squared_error',
# )


grid_search = GridSearchCV(
    estimator=model,
    param_grid=param_grid,
    scoring="neg_mean_absolute_error",
    n_jobs=-1,
    verbose=2
)

# Expanded param grid
# param_grid = {
#     "n_estimators": [100, 300, 500],
#     "max_depth": [3, 5, 7],
#     "learning_rate": [0.01, 0.05, 0.1],
#     "subsample": [0.8, 1.0],
#     "colsample_bytree": [0.8, 1.0],
#     "min_child_weight": [1, 3, 5],
#     "reg_alpha": [0, 0.01, 0.1],
#     "reg_lambda": [1, 5, 10]
# }


grid_search.fit(X_train, y_train)


best_model = grid_search.best_estimator_

print("Best params:")
print(grid_search.best_params_)

print("Best MAE:")
print(-grid_search.best_score_)
# Out:
# Fitting 5 folds for each of 192 candidates, totalling 960 fits
# Best params:
# {'colsample_bytree': 1.0, 'learning_rate': 0.03, 'max_depth': 5, 'min_child_weight': 1, 'n_estimators': 200, 'reg_lambda': 5, 'subsample': 0.8}
# Best MAE:
# 1.885862360152459
# CPU times: user 12.2 s, sys: 6.7 s, total: 18.9 s
# Wall time: 38min 56s
# [CV] END colsample_bytree=0.8, learning_rate=0.03, max_depth=3, min_child_weight=1, n_estimators=200, reg_lambda=1, subsample=0.8; total time=   3.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.03, max_depth=3, min_child_weight=1, n_estimators=200, reg_lambda=5, subsample=0.8; total time=   3.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.03, max_depth=3, min_child_weight=1, n_estimators=500, reg_lambda=1, subsample=0.8; total time=   7.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.03, max_depth=3, min_child_weight=1, n_estimators=500, reg_lambda=1, subsample=1.0; total time=   7.0s
# [CV] END colsample_bytree=0.8, learning_rate=0.03, max_depth=3, min_child_weight=1, n_estimators=500, reg_lambda=5, subsample=1.0; total time=   7.9s
# [CV] END colsample_bytree=0.8, learning_rate=0.03, max_depth=3, min_child_weight=5, n_estimators=200, reg_lambda=1, subsample=1.0; total time=   3.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.03, max_depth=3, min_child_weight=5, n_estimators=200, reg_lambda=5, subsample=0.8; total time=   3.9s
# [CV] END colsample_bytree=0.8, learning_rate=0.03, max_depth=3, min_child_weight=5, n_estimators=500, reg_lambda=1, subsample=1.0; total time=  11.8s
# [CV] END colsample_bytree=0.8, learning_rate=0.03, max_depth=3, min_child_weight=5, n_estimators=500, reg_lambda=1, subsample=1.0; total time=  12.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.03, max_depth=3, min_child_weight=5, n_estimators=500, reg_lambda=5, subsample=1.0; total time=  46.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.03, max_depth=5, min_child_weight=1, n_estimators=200, reg_lambda=1, subsample=1.0; total time=  26.9s
# [CV] END colsample_bytree=0.8, learning_rate=0.03, max_depth=5, min_child_weight=1, n_estimators=200, reg_lambda=5, subsample=1.0; total time=  21.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.03, max_depth=5, min_child_weight=1, n_estimators=500, reg_lambda=1, subsample=1.0; total time=  50.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.03, max_depth=5, min_child_weight=1, n_estimators=500, reg_lambda=5, subsample=0.8; total time= 1.0min
# [CV] END colsample_bytree=0.8, learning_rate=0.03, max_depth=5, min_child_weight=5, n_estimators=200, reg_lambda=1, subsample=0.8; total time=  16.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.03, max_depth=5, min_child_weight=5, n_estimators=200, reg_lambda=1, subsample=0.8; total time=  14.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.03, max_depth=5, min_child_weight=5, n_estimators=200, reg_lambda=5, subsample=0.8; total time=  14.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.03, max_depth=5, min_child_weight=5, n_estimators=500, reg_lambda=1, subsample=0.8; total time=  33.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.03, max_depth=5, min_child_weight=5, n_estimators=500, reg_lambda=1, subsample=1.0; total time=  35.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.03, max_depth=5, min_child_weight=5, n_estimators=500, reg_lambda=5, subsample=1.0; total time=  29.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=3, min_child_weight=1, n_estimators=200, reg_lambda=1, subsample=1.0; total time=   9.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=3, min_child_weight=1, n_estimators=200, reg_lambda=5, subsample=1.0; total time=   8.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=3, min_child_weight=1, n_estimators=500, reg_lambda=1, subsample=0.8; total time= 1.1min
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=3, min_child_weight=1, n_estimators=500, reg_lambda=5, subsample=0.8; total time=  25.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=3, min_child_weight=5, n_estimators=200, reg_lambda=1, subsample=0.8; total time=  11.0s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=3, min_child_weight=5, n_estimators=200, reg_lambda=1, subsample=1.0; total time=   9.8s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=3, min_child_weight=5, n_estimators=200, reg_lambda=5, subsample=1.0; total time=   9.8s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=3, min_child_weight=5, n_estimators=500, reg_lambda=1, subsample=0.8; total time=  24.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=3, min_child_weight=5, n_estimators=500, reg_lambda=5, subsample=0.8; total time=  24.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=3, min_child_weight=5, n_estimators=500, reg_lambda=5, subsample=1.0; total time=  24.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=200, reg_lambda=5, subsample=0.8; total time=  14.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=200, reg_lambda=5, subsample=1.0; total time=  13.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=500, reg_lambda=1, subsample=1.0; total time=  31.8s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=500, reg_lambda=5, subsample=0.8; total time=  35.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, min_child_weight=5, n_estimators=200, reg_lambda=1, subsample=0.8; total time=  16.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, min_child_weight=5, n_estimators=200, reg_lambda=1, subsample=1.0; total time=  15.0s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, min_child_weight=5, n_estimators=200, reg_lambda=5, subsample=1.0; total time=  16.8s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, min_child_weight=5, n_estimators=500, reg_lambda=1, subsample=0.8; total time=  40.8s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, min_child_weight=5, n_estimators=500, reg_lambda=1, subsample=1.0; total time=  44.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, min_child_weight=5, n_estimators=500, reg_lambda=5, subsample=1.0; total time=  36.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=200, reg_lambda=1, subsample=1.0; total time=  11.9s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=200, reg_lambda=5, subsample=1.0; total time=  11.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=500, reg_lambda=1, subsample=0.8; total time=  29.0s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=500, reg_lambda=5, subsample=0.8; total time=  28.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=3, min_child_weight=5, n_estimators=200, reg_lambda=1, subsample=0.8; total time=  13.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=3, min_child_weight=5, n_estimators=200, reg_lambda=1, subsample=1.0; total time=  13.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=3, min_child_weight=5, n_estimators=200, reg_lambda=5, subsample=0.8; total time=  13.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=3, min_child_weight=5, n_estimators=500, reg_lambda=1, subsample=0.8; total time=  29.9s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=3, min_child_weight=5, n_estimators=500, reg_lambda=1, subsample=1.0; total time=  30.8s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=3, min_child_weight=5, n_estimators=500, reg_lambda=5, subsample=1.0; total time=  21.8s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=200, reg_lambda=5, subsample=0.8; total time=  13.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=200, reg_lambda=5, subsample=1.0; total time=  12.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=500, reg_lambda=1, subsample=1.0; total time=  27.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=500, reg_lambda=5, subsample=0.8; total time=  27.9s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=200, reg_lambda=1, subsample=0.8; total time=  12.8s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=200, reg_lambda=1, subsample=1.0; total time=  11.0s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=200, reg_lambda=5, subsample=1.0; total time=  11.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=500, reg_lambda=1, subsample=0.8; total time=  27.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=500, reg_lambda=5, subsample=0.8; total time=  26.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=500, reg_lambda=5, subsample=1.0; total time=  25.4s
# [CV] END colsample_bytree=1.0, learning_rate=0.03, max_depth=3, min_child_weight=1, n_estimators=200, reg_lambda=5, subsample=0.8; total time=   8.9s
# [CV] END colsample_bytree=1.0, learning_rate=0.03, max_depth=3, min_child_weight=1, n_estimators=200, reg_lambda=5, subsample=1.0; total time=   8.4s
# [CV] END colsample_bytree=1.0, learning_rate=0.03, max_depth=3, min_child_weight=1, n_estimators=500, reg_lambda=1, subsample=1.0; total time=  19.0s
# [CV] END colsample_bytree=1.0, learning_rate=0.03, max_depth=3, min_child_weight=1, n_estimators=500, reg_lambda=5, subsample=1.0; total time=  18.8s
# [CV] END colsample_bytree=1.0, learning_rate=0.03, max_depth=3, min_child_weight=5, n_estimators=200, reg_lambda=1, subsample=0.8; total time=  10.8s
# [CV] END colsample_bytree=1.0, learning_rate=0.03, max_depth=3, min_child_weight=5, n_estimators=200, reg_lambda=1, subsample=1.0; total time=   9.6s
# [CV] END colsample_bytree=1.0, learning_rate=0.03, max_depth=3, min_child_weight=5, n_estimators=200, reg_lambda=5, subsample=0.8; total time=  10.2s
# [CV] END colsample_bytree=1.0, learning_rate=0.03, max_depth=3, min_child_weight=5, n_estimators=500, reg_lambda=1, subsample=0.8; total time=  22.6s
# [CV] END colsample_bytree=1.0, learning_rate=0.03, max_depth=3, min_child_weight=5, n_estimators=500, reg_lambda=1, subsample=1.0; total time=  21.0s
# [CV] END colsample_bytree=1.0, learning_rate=0.03, max_depth=3, min_child_weight=5, n_estimators=500, reg_lambda=5, subsample=1.0; total time=  19.9s
# [CV] END colsample_bytree=1.0, learning_rate=0.03, max_depth=5, min_child_weight=1, n_estimators=200, reg_lambda=1, subsample=1.0; total time=  10.5s
# [CV] END colsample_bytree=1.0, learning_rate=0.03, max_depth=5, min_child_weight=1, n_estimators=200, reg_lambda=5, subsample=1.0; total time=  11.8s
# [CV] END colsample_bytree=1.0, learning_rate=0.03, max_depth=5, min_child_weight=1, n_estimators=500, reg_lambda=1, subsample=0.8; total time=  27.6s
# [CV] END colsample_bytree=1.0, learning_rate=0.03, max_depth=5, min_child_weight=1, n_estimators=500, reg_lambda=5, subsample=0.8; total time=  36.0s
# [CV] END colsample_bytree=1.0, learning_rate=0.03, max_depth=5, min_child_weight=5, n_estimators=200, reg_lambda=1, subsample=0.8; total time=  14.0s
# [CV] END colsample_bytree=1.0, learning_rate=0.03, max_depth=5, min_child_weight=5, n_estimators=200, reg_lambda=1, subsample=1.0; total time=  12.4s
# [CV] END colsample_bytree=1.0, learning_rate=0.03, max_depth=5, min_child_weight=5, n_estimators=200, reg_lambda=5, subsample=0.8; total time=  12.7s
# [CV] END colsample_bytree=1.0, learning_rate=0.03, max_depth=5, min_child_weight=5, n_estimators=500, reg_lambda=1, subsample=0.8; total time=  27.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.03, max_depth=5, min_child_weight=5, n_estimators=500, reg_lambda=5, subsample=0.8; total time=  30.4s
# [CV] END colsample_bytree=1.0, learning_rate=0.03, max_depth=5, min_child_weight=5, n_estimators=500, reg_lambda=5, subsample=1.0; total time=  21.9s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=3, min_child_weight=1, n_estimators=200, reg_lambda=5, subsample=0.8; total time=   7.0s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=3, min_child_weight=1, n_estimators=200, reg_lambda=5, subsample=1.0; total time=   6.3s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=3, min_child_weight=1, n_estimators=500, reg_lambda=1, subsample=1.0; total time=  14.7s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=3, min_child_weight=1, n_estimators=500, reg_lambda=5, subsample=1.0; total time=  14.8s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=3, min_child_weight=5, n_estimators=200, reg_lambda=1, subsample=0.8; total time=   8.8s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=3, min_child_weight=5, n_estimators=200, reg_lambda=1, subsample=1.0; total time=   7.6s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=3, min_child_weight=5, n_estimators=200, reg_lambda=5, subsample=0.8; total time=   8.6s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=3, min_child_weight=5, n_estimators=500, reg_lambda=1, subsample=0.8; total time=  18.4s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=3, min_child_weight=5, n_estimators=500, reg_lambda=1, subsample=1.0; total time=  16.8s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=3, min_child_weight=5, n_estimators=500, reg_lambda=5, subsample=1.0; total time=  14.4s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=200, reg_lambda=1, subsample=1.0; total time=   8.5s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=200, reg_lambda=5, subsample=1.0; total time=   8.5s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=500, reg_lambda=1, subsample=0.8; total time=  20.5s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=500, reg_lambda=5, subsample=0.8; total time=  22.0s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=500, reg_lambda=5, subsample=1.0; total time=  23.8s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=5, min_child_weight=5, n_estimators=200, reg_lambda=5, subsample=0.8; total time=  10.3s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=5, min_child_weight=5, n_estimators=200, reg_lambda=5, subsample=1.0; total time=   9.9s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=5, min_child_weight=5, n_estimators=500, reg_lambda=1, subsample=1.0; total time=  22.6s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=5, min_child_weight=5, n_estimators=500, reg_lambda=5, subsample=0.8; total time=  24.8s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=200, reg_lambda=1, subsample=0.8; total time=   8.8s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=200, reg_lambda=1, subsample=1.0; total time=   7.7s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=200, reg_lambda=5, subsample=0.8; total time=  11.2s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=500, reg_lambda=1, subsample=0.8; total time=  32.4s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=500, reg_lambda=1, subsample=1.0; total time=  19.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=500, reg_lambda=5, subsample=1.0; total time=  30.8s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=3, min_child_weight=5, n_estimators=200, reg_lambda=1, subsample=1.0; total time=  13.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=3, min_child_weight=5, n_estimators=200, reg_lambda=5, subsample=1.0; total time=  11.9s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=3, min_child_weight=5, n_estimators=500, reg_lambda=1, subsample=0.8; total time=  28.0s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=3, min_child_weight=5, n_estimators=500, reg_lambda=5, subsample=0.8; total time=  18.7s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=200, reg_lambda=1, subsample=0.8; total time=  10.4s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=200, reg_lambda=1, subsample=1.0; total time=   9.8s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=200, reg_lambda=5, subsample=0.8; total time=  10.3s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=500, reg_lambda=1, subsample=0.8; total time=  26.0s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=500, reg_lambda=1, subsample=1.0; total time=  23.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=500, reg_lambda=5, subsample=1.0; total time=  30.4s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=200, reg_lambda=1, subsample=1.0; total time=  14.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=200, reg_lambda=5, subsample=1.0; total time=  22.5s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=500, reg_lambda=1, subsample=0.8; total time=  36.6s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=500, reg_lambda=5, subsample=0.8; total time=  31.8s
# [CV] END colsample_bytree=0.8, learning_rate=0.03, max_depth=3, min_child_weight=1, n_estimators=200, reg_lambda=1, subsample=1.0; total time=   3.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.03, max_depth=3, min_child_weight=1, n_estimators=200, reg_lambda=1, subsample=1.0; total time=   3.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.03, max_depth=3, min_child_weight=1, n_estimators=200, reg_lambda=5, subsample=1.0; total time=   3.0s
# [CV] END colsample_bytree=0.8, learning_rate=0.03, max_depth=3, min_child_weight=1, n_estimators=500, reg_lambda=1, subsample=1.0; total time=   6.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.03, max_depth=3, min_child_weight=1, n_estimators=500, reg_lambda=5, subsample=0.8; total time=   8.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.03, max_depth=3, min_child_weight=5, n_estimators=200, reg_lambda=1, subsample=0.8; total time=   4.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.03, max_depth=3, min_child_weight=5, n_estimators=200, reg_lambda=1, subsample=1.0; total time=   3.8s
# [CV] END colsample_bytree=0.8, learning_rate=0.03, max_depth=3, min_child_weight=5, n_estimators=200, reg_lambda=5, subsample=1.0; total time=   3.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.03, max_depth=3, min_child_weight=5, n_estimators=500, reg_lambda=1, subsample=0.8; total time=  12.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.03, max_depth=3, min_child_weight=5, n_estimators=500, reg_lambda=5, subsample=0.8; total time=  13.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.03, max_depth=5, min_child_weight=1, n_estimators=200, reg_lambda=1, subsample=0.8; total time=  14.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.03, max_depth=5, min_child_weight=1, n_estimators=200, reg_lambda=1, subsample=0.8; total time=  47.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.03, max_depth=5, min_child_weight=1, n_estimators=200, reg_lambda=5, subsample=0.8; total time=  23.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.03, max_depth=5, min_child_weight=1, n_estimators=500, reg_lambda=1, subsample=0.8; total time=  47.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.03, max_depth=5, min_child_weight=1, n_estimators=500, reg_lambda=5, subsample=0.8; total time= 1.1min
# [CV] END colsample_bytree=0.8, learning_rate=0.03, max_depth=5, min_child_weight=1, n_estimators=500, reg_lambda=5, subsample=1.0; total time=  32.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.03, max_depth=5, min_child_weight=5, n_estimators=200, reg_lambda=5, subsample=0.8; total time=  14.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.03, max_depth=5, min_child_weight=5, n_estimators=200, reg_lambda=5, subsample=1.0; total time=  14.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.03, max_depth=5, min_child_weight=5, n_estimators=500, reg_lambda=1, subsample=1.0; total time=  32.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.03, max_depth=5, min_child_weight=5, n_estimators=500, reg_lambda=5, subsample=1.0; total time=  34.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=3, min_child_weight=1, n_estimators=200, reg_lambda=1, subsample=0.8; total time=  11.9s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=3, min_child_weight=1, n_estimators=200, reg_lambda=1, subsample=1.0; total time=   9.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=3, min_child_weight=1, n_estimators=200, reg_lambda=5, subsample=0.8; total time=   9.9s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=3, min_child_weight=1, n_estimators=500, reg_lambda=1, subsample=0.8; total time=  58.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=3, min_child_weight=1, n_estimators=500, reg_lambda=5, subsample=0.8; total time=  29.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=3, min_child_weight=1, n_estimators=500, reg_lambda=5, subsample=1.0; total time=  21.9s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=3, min_child_weight=5, n_estimators=200, reg_lambda=5, subsample=0.8; total time=  10.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=3, min_child_weight=5, n_estimators=200, reg_lambda=5, subsample=1.0; total time=  10.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=3, min_child_weight=5, n_estimators=500, reg_lambda=1, subsample=1.0; total time=  23.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=3, min_child_weight=5, n_estimators=500, reg_lambda=5, subsample=1.0; total time=  23.9s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=200, reg_lambda=1, subsample=0.8; total time=  14.9s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=200, reg_lambda=1, subsample=1.0; total time=  13.8s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=200, reg_lambda=5, subsample=0.8; total time=  15.0s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=500, reg_lambda=1, subsample=0.8; total time=  33.9s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=500, reg_lambda=5, subsample=0.8; total time=  35.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=500, reg_lambda=5, subsample=1.0; total time=  32.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, min_child_weight=5, n_estimators=200, reg_lambda=5, subsample=0.8; total time=  17.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, min_child_weight=5, n_estimators=200, reg_lambda=5, subsample=1.0; total time=  16.0s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, min_child_weight=5, n_estimators=500, reg_lambda=1, subsample=1.0; total time=  48.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, min_child_weight=5, n_estimators=500, reg_lambda=5, subsample=1.0; total time=  36.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=200, reg_lambda=1, subsample=0.8; total time=  14.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=200, reg_lambda=1, subsample=1.0; total time=  12.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=200, reg_lambda=5, subsample=0.8; total time=  12.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=500, reg_lambda=1, subsample=0.8; total time=  28.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=500, reg_lambda=5, subsample=0.8; total time=  28.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=500, reg_lambda=5, subsample=1.0; total time=  26.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=3, min_child_weight=5, n_estimators=200, reg_lambda=5, subsample=0.8; total time=  14.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=3, min_child_weight=5, n_estimators=200, reg_lambda=5, subsample=1.0; total time=  12.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=3, min_child_weight=5, n_estimators=500, reg_lambda=1, subsample=1.0; total time=  30.0s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=3, min_child_weight=5, n_estimators=500, reg_lambda=5, subsample=0.8; total time=  29.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=200, reg_lambda=1, subsample=0.8; total time=  13.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=200, reg_lambda=1, subsample=1.0; total time=  12.0s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=200, reg_lambda=5, subsample=1.0; total time=  12.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=500, reg_lambda=1, subsample=0.8; total time=  29.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=500, reg_lambda=1, subsample=1.0; total time=  27.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=500, reg_lambda=5, subsample=1.0; total time=  25.8s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=200, reg_lambda=1, subsample=1.0; total time=  11.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=200, reg_lambda=5, subsample=1.0; total time=  11.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=500, reg_lambda=1, subsample=1.0; total time=  25.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=500, reg_lambda=5, subsample=0.8; total time=  27.3s
# [CV] END colsample_bytree=1.0, learning_rate=0.03, max_depth=3, min_child_weight=1, n_estimators=200, reg_lambda=1, subsample=0.8; total time=   9.8s
# [CV] END colsample_bytree=1.0, learning_rate=0.03, max_depth=3, min_child_weight=1, n_estimators=200, reg_lambda=1, subsample=0.8; total time=   9.2s
# [CV] END colsample_bytree=1.0, learning_rate=0.03, max_depth=3, min_child_weight=1, n_estimators=200, reg_lambda=5, subsample=0.8; total time=   9.6s
# [CV] END colsample_bytree=1.0, learning_rate=0.03, max_depth=3, min_child_weight=1, n_estimators=500, reg_lambda=1, subsample=0.8; total time=  20.8s
# [CV] END colsample_bytree=1.0, learning_rate=0.03, max_depth=3, min_child_weight=1, n_estimators=500, reg_lambda=5, subsample=0.8; total time=  20.4s
# [CV] END colsample_bytree=1.0, learning_rate=0.03, max_depth=3, min_child_weight=1, n_estimators=500, reg_lambda=5, subsample=1.0; total time=  20.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.03, max_depth=3, min_child_weight=5, n_estimators=200, reg_lambda=5, subsample=0.8; total time=   9.8s
# [CV] END colsample_bytree=1.0, learning_rate=0.03, max_depth=3, min_child_weight=5, n_estimators=200, reg_lambda=5, subsample=1.0; total time=   9.5s
# [CV] END colsample_bytree=1.0, learning_rate=0.03, max_depth=3, min_child_weight=5, n_estimators=500, reg_lambda=1, subsample=1.0; total time=  21.3s
# [CV] END colsample_bytree=1.0, learning_rate=0.03, max_depth=3, min_child_weight=5, n_estimators=500, reg_lambda=5, subsample=0.8; total time=  21.7s
# [CV] END colsample_bytree=1.0, learning_rate=0.03, max_depth=5, min_child_weight=1, n_estimators=200, reg_lambda=1, subsample=0.8; total time=  12.6s
# [CV] END colsample_bytree=1.0, learning_rate=0.03, max_depth=5, min_child_weight=1, n_estimators=200, reg_lambda=1, subsample=1.0; total time=  10.5s
# [CV] END colsample_bytree=1.0, learning_rate=0.03, max_depth=5, min_child_weight=1, n_estimators=200, reg_lambda=5, subsample=1.0; total time=  11.6s
# [CV] END colsample_bytree=1.0, learning_rate=0.03, max_depth=5, min_child_weight=1, n_estimators=500, reg_lambda=1, subsample=0.8; total time=  28.0s
# [CV] END colsample_bytree=1.0, learning_rate=0.03, max_depth=5, min_child_weight=1, n_estimators=500, reg_lambda=5, subsample=0.8; total time=  34.4s
# [CV] END colsample_bytree=1.0, learning_rate=0.03, max_depth=5, min_child_weight=1, n_estimators=500, reg_lambda=5, subsample=1.0; total time=  29.0s
# [CV] END colsample_bytree=1.0, learning_rate=0.03, max_depth=5, min_child_weight=5, n_estimators=200, reg_lambda=5, subsample=0.8; total time=  13.0s
# [CV] END colsample_bytree=1.0, learning_rate=0.03, max_depth=5, min_child_weight=5, n_estimators=200, reg_lambda=5, subsample=1.0; total time=  11.7s
# [CV] END colsample_bytree=1.0, learning_rate=0.03, max_depth=5, min_child_weight=5, n_estimators=500, reg_lambda=1, subsample=1.0; total time=  29.4s
# [CV] END colsample_bytree=1.0, learning_rate=0.03, max_depth=5, min_child_weight=5, n_estimators=500, reg_lambda=5, subsample=1.0; total time=  25.3s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=3, min_child_weight=1, n_estimators=200, reg_lambda=1, subsample=0.8; total time=   8.6s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=3, min_child_weight=1, n_estimators=200, reg_lambda=1, subsample=1.0; total time=   6.7s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=3, min_child_weight=1, n_estimators=200, reg_lambda=5, subsample=0.8; total time=   7.3s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=3, min_child_weight=1, n_estimators=500, reg_lambda=1, subsample=0.8; total time=  15.9s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=3, min_child_weight=1, n_estimators=500, reg_lambda=5, subsample=0.8; total time=  15.5s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=3, min_child_weight=1, n_estimators=500, reg_lambda=5, subsample=1.0; total time=  16.9s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=3, min_child_weight=5, n_estimators=200, reg_lambda=5, subsample=0.8; total time=   8.3s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=3, min_child_weight=5, n_estimators=200, reg_lambda=5, subsample=1.0; total time=   8.7s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=3, min_child_weight=5, n_estimators=500, reg_lambda=1, subsample=1.0; total time=  17.8s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=3, min_child_weight=5, n_estimators=500, reg_lambda=5, subsample=0.8; total time=  17.0s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=200, reg_lambda=1, subsample=0.8; total time=   8.4s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=200, reg_lambda=1, subsample=1.0; total time=   8.2s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=200, reg_lambda=5, subsample=0.8; total time=   9.5s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=500, reg_lambda=1, subsample=0.8; total time=  21.7s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=500, reg_lambda=5, subsample=0.8; total time=  22.9s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=5, min_child_weight=5, n_estimators=200, reg_lambda=1, subsample=0.8; total time=  12.3s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=5, min_child_weight=5, n_estimators=200, reg_lambda=1, subsample=1.0; total time=  11.0s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=5, min_child_weight=5, n_estimators=200, reg_lambda=5, subsample=1.0; total time=   9.9s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=5, min_child_weight=5, n_estimators=500, reg_lambda=1, subsample=0.8; total time=  24.4s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=5, min_child_weight=5, n_estimators=500, reg_lambda=5, subsample=0.8; total time=  25.2s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=5, min_child_weight=5, n_estimators=500, reg_lambda=5, subsample=1.0; total time=  23.3s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=200, reg_lambda=5, subsample=0.8; total time=  11.6s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=500, reg_lambda=1, subsample=0.8; total time=  32.9s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=500, reg_lambda=5, subsample=0.8; total time=  21.3s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=500, reg_lambda=5, subsample=1.0; total time=  31.4s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=3, min_child_weight=5, n_estimators=200, reg_lambda=5, subsample=0.8; total time=  12.8s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=3, min_child_weight=5, n_estimators=200, reg_lambda=5, subsample=1.0; total time=  11.5s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=3, min_child_weight=5, n_estimators=500, reg_lambda=1, subsample=1.0; total time=  26.2s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=3, min_child_weight=5, n_estimators=500, reg_lambda=5, subsample=0.8; total time=  18.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=200, reg_lambda=1, subsample=0.8; total time=  10.9s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=200, reg_lambda=1, subsample=1.0; total time=  10.2s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=200, reg_lambda=5, subsample=0.8; total time=   9.8s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=500, reg_lambda=1, subsample=0.8; total time=  26.8s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=500, reg_lambda=1, subsample=1.0; total time=  23.8s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=500, reg_lambda=5, subsample=1.0; total time=  29.6s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=200, reg_lambda=1, subsample=1.0; total time=  14.7s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=200, reg_lambda=5, subsample=1.0; total time=  22.8s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=500, reg_lambda=1, subsample=1.0; total time=  35.4s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=500, reg_lambda=5, subsample=0.8; total time=  32.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.03, max_depth=3, min_child_weight=1, n_estimators=200, reg_lambda=1, subsample=0.8; total time=   3.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.03, max_depth=3, min_child_weight=1, n_estimators=200, reg_lambda=5, subsample=0.8; total time=   3.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.03, max_depth=3, min_child_weight=1, n_estimators=500, reg_lambda=1, subsample=0.8; total time=   7.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.03, max_depth=3, min_child_weight=1, n_estimators=500, reg_lambda=5, subsample=0.8; total time=   7.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.03, max_depth=3, min_child_weight=1, n_estimators=500, reg_lambda=5, subsample=1.0; total time=   7.8s
# [CV] END colsample_bytree=0.8, learning_rate=0.03, max_depth=3, min_child_weight=5, n_estimators=200, reg_lambda=5, subsample=0.8; total time=   3.9s
# [CV] END colsample_bytree=0.8, learning_rate=0.03, max_depth=3, min_child_weight=5, n_estimators=200, reg_lambda=5, subsample=1.0; total time=   3.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.03, max_depth=3, min_child_weight=5, n_estimators=500, reg_lambda=1, subsample=1.0; total time=  11.9s
# [CV] END colsample_bytree=0.8, learning_rate=0.03, max_depth=3, min_child_weight=5, n_estimators=500, reg_lambda=5, subsample=0.8; total time=  13.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.03, max_depth=5, min_child_weight=1, n_estimators=200, reg_lambda=1, subsample=0.8; total time=  15.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.03, max_depth=5, min_child_weight=1, n_estimators=200, reg_lambda=1, subsample=1.0; total time=  46.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.03, max_depth=5, min_child_weight=1, n_estimators=200, reg_lambda=5, subsample=0.8; total time=  24.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.03, max_depth=5, min_child_weight=1, n_estimators=500, reg_lambda=1, subsample=0.8; total time=  47.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.03, max_depth=5, min_child_weight=1, n_estimators=500, reg_lambda=5, subsample=0.8; total time= 1.1min
# [CV] END colsample_bytree=0.8, learning_rate=0.03, max_depth=5, min_child_weight=1, n_estimators=500, reg_lambda=5, subsample=1.0; total time=  32.0s
# [CV] END colsample_bytree=0.8, learning_rate=0.03, max_depth=5, min_child_weight=5, n_estimators=200, reg_lambda=5, subsample=0.8; total time=  14.0s
# [CV] END colsample_bytree=0.8, learning_rate=0.03, max_depth=5, min_child_weight=5, n_estimators=200, reg_lambda=5, subsample=1.0; total time=  14.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.03, max_depth=5, min_child_weight=5, n_estimators=500, reg_lambda=1, subsample=1.0; total time=  32.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.03, max_depth=5, min_child_weight=5, n_estimators=500, reg_lambda=5, subsample=0.8; total time=  34.9s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=3, min_child_weight=1, n_estimators=200, reg_lambda=1, subsample=0.8; total time=  12.0s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=3, min_child_weight=1, n_estimators=200, reg_lambda=1, subsample=1.0; total time=   9.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=3, min_child_weight=1, n_estimators=200, reg_lambda=5, subsample=0.8; total time=   9.8s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=3, min_child_weight=1, n_estimators=500, reg_lambda=1, subsample=0.8; total time=  57.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=3, min_child_weight=1, n_estimators=500, reg_lambda=1, subsample=1.0; total time=  29.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=3, min_child_weight=1, n_estimators=500, reg_lambda=5, subsample=1.0; total time=  21.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=3, min_child_weight=5, n_estimators=200, reg_lambda=1, subsample=1.0; total time=  10.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=3, min_child_weight=5, n_estimators=200, reg_lambda=5, subsample=1.0; total time=   9.8s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=3, min_child_weight=5, n_estimators=500, reg_lambda=1, subsample=0.8; total time=  24.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=3, min_child_weight=5, n_estimators=500, reg_lambda=5, subsample=0.8; total time=  24.0s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=200, reg_lambda=1, subsample=0.8; total time=  14.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=200, reg_lambda=1, subsample=0.8; total time=  14.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=200, reg_lambda=5, subsample=0.8; total time=  15.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=500, reg_lambda=1, subsample=0.8; total time=  33.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=500, reg_lambda=1, subsample=1.0; total time=  34.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=500, reg_lambda=5, subsample=1.0; total time=  31.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, min_child_weight=5, n_estimators=200, reg_lambda=1, subsample=1.0; total time=  16.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, min_child_weight=5, n_estimators=200, reg_lambda=5, subsample=1.0; total time=  16.8s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, min_child_weight=5, n_estimators=500, reg_lambda=1, subsample=1.0; total time=  48.0s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, min_child_weight=5, n_estimators=500, reg_lambda=5, subsample=0.8; total time=  38.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=200, reg_lambda=1, subsample=0.8; total time=  13.9s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=200, reg_lambda=1, subsample=0.8; total time=  13.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=200, reg_lambda=5, subsample=0.8; total time=  12.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=200, reg_lambda=5, subsample=1.0; total time=  12.0s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=500, reg_lambda=1, subsample=1.0; total time=  28.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=500, reg_lambda=5, subsample=0.8; total time=  28.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=3, min_child_weight=5, n_estimators=200, reg_lambda=1, subsample=0.8; total time=  13.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=3, min_child_weight=5, n_estimators=200, reg_lambda=1, subsample=1.0; total time=  13.8s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=3, min_child_weight=5, n_estimators=200, reg_lambda=5, subsample=1.0; total time=  13.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=3, min_child_weight=5, n_estimators=500, reg_lambda=1, subsample=0.8; total time=  29.9s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=3, min_child_weight=5, n_estimators=500, reg_lambda=5, subsample=0.8; total time=  31.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=3, min_child_weight=5, n_estimators=500, reg_lambda=5, subsample=1.0; total time=  21.0s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=200, reg_lambda=5, subsample=0.8; total time=  13.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=200, reg_lambda=5, subsample=1.0; total time=  12.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=500, reg_lambda=1, subsample=1.0; total time=  27.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=500, reg_lambda=5, subsample=1.0; total time=  25.9s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=200, reg_lambda=1, subsample=0.8; total time=  12.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=200, reg_lambda=1, subsample=0.8; total time=  11.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=200, reg_lambda=5, subsample=0.8; total time=  11.8s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=500, reg_lambda=1, subsample=0.8; total time=  26.8s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=500, reg_lambda=1, subsample=1.0; total time=  25.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=500, reg_lambda=5, subsample=1.0; total time=  26.0s
# [CV] END colsample_bytree=1.0, learning_rate=0.03, max_depth=3, min_child_weight=1, n_estimators=200, reg_lambda=1, subsample=1.0; total time=   8.9s
# [CV] END colsample_bytree=1.0, learning_rate=0.03, max_depth=3, min_child_weight=1, n_estimators=200, reg_lambda=5, subsample=1.0; total time=   7.9s
# [CV] END colsample_bytree=1.0, learning_rate=0.03, max_depth=3, min_child_weight=1, n_estimators=500, reg_lambda=1, subsample=0.8; total time=  20.3s
# [CV] END colsample_bytree=1.0, learning_rate=0.03, max_depth=3, min_child_weight=1, n_estimators=500, reg_lambda=5, subsample=0.8; total time=  20.8s
# [CV] END colsample_bytree=1.0, learning_rate=0.03, max_depth=3, min_child_weight=5, n_estimators=200, reg_lambda=1, subsample=0.8; total time=  10.9s
# [CV] END colsample_bytree=1.0, learning_rate=0.03, max_depth=3, min_child_weight=5, n_estimators=200, reg_lambda=1, subsample=1.0; total time=   9.8s
# [CV] END colsample_bytree=1.0, learning_rate=0.03, max_depth=3, min_child_weight=5, n_estimators=200, reg_lambda=5, subsample=1.0; total time=   9.3s
# [CV] END colsample_bytree=1.0, learning_rate=0.03, max_depth=3, min_child_weight=5, n_estimators=500, reg_lambda=1, subsample=0.8; total time=  22.6s
# [CV] END colsample_bytree=1.0, learning_rate=0.03, max_depth=3, min_child_weight=5, n_estimators=500, reg_lambda=5, subsample=0.8; total time=  22.3s
# [CV] END colsample_bytree=1.0, learning_rate=0.03, max_depth=5, min_child_weight=1, n_estimators=200, reg_lambda=1, subsample=0.8; total time=  11.6s
# [CV] END colsample_bytree=1.0, learning_rate=0.03, max_depth=5, min_child_weight=1, n_estimators=200, reg_lambda=1, subsample=0.8; total time=  11.2s
# [CV] END colsample_bytree=1.0, learning_rate=0.03, max_depth=5, min_child_weight=1, n_estimators=200, reg_lambda=5, subsample=0.8; total time=  12.8s
# [CV] END colsample_bytree=1.0, learning_rate=0.03, max_depth=5, min_child_weight=1, n_estimators=500, reg_lambda=1, subsample=0.8; total time=  28.2s
# [CV] END colsample_bytree=1.0, learning_rate=0.03, max_depth=5, min_child_weight=1, n_estimators=500, reg_lambda=1, subsample=1.0; total time=  33.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.03, max_depth=5, min_child_weight=1, n_estimators=500, reg_lambda=5, subsample=1.0; total time=  28.8s
# [CV] END colsample_bytree=1.0, learning_rate=0.03, max_depth=5, min_child_weight=5, n_estimators=200, reg_lambda=1, subsample=1.0; total time=  12.3s
# [CV] END colsample_bytree=1.0, learning_rate=0.03, max_depth=5, min_child_weight=5, n_estimators=200, reg_lambda=5, subsample=1.0; total time=  11.6s
# [CV] END colsample_bytree=1.0, learning_rate=0.03, max_depth=5, min_child_weight=5, n_estimators=500, reg_lambda=1, subsample=0.8; total time=  29.2s
# [CV] END colsample_bytree=1.0, learning_rate=0.03, max_depth=5, min_child_weight=5, n_estimators=500, reg_lambda=5, subsample=0.8; total time=  28.2s
# ...
# [CV] END colsample_bytree=0.8, learning_rate=0.03, max_depth=5, min_child_weight=1, n_estimators=500, reg_lambda=5, subsample=1.0; total time=  32.0s
# [CV] END colsample_bytree=0.8, learning_rate=0.03, max_depth=5, min_child_weight=5, n_estimators=200, reg_lambda=1, subsample=1.0; total time=  14.0s
# [CV] END colsample_bytree=0.8, learning_rate=0.03, max_depth=5, min_child_weight=5, n_estimators=200, reg_lambda=5, subsample=1.0; total time=  13.9s
# [CV] END colsample_bytree=0.8, learning_rate=0.03, max_depth=5, min_child_weight=5, n_estimators=500, reg_lambda=1, subsample=0.8; total time=  33.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.03, max_depth=5, min_child_weight=5, n_estimators=500, reg_lambda=5, subsample=0.8; total time=  35.8s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=3, min_child_weight=1, n_estimators=200, reg_lambda=1, subsample=0.8; total time=  11.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=3, min_child_weight=1, n_estimators=200, reg_lambda=1, subsample=1.0; total time=  10.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=3, min_child_weight=1, n_estimators=200, reg_lambda=5, subsample=0.8; total time=   9.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=3, min_child_weight=1, n_estimators=200, reg_lambda=5, subsample=1.0; total time=   9.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=3, min_child_weight=1, n_estimators=500, reg_lambda=1, subsample=1.0; total time= 1.0min
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=3, min_child_weight=1, n_estimators=500, reg_lambda=5, subsample=1.0; total time=  23.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=3, min_child_weight=5, n_estimators=200, reg_lambda=1, subsample=0.8; total time=  11.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=3, min_child_weight=5, n_estimators=200, reg_lambda=1, subsample=0.8; total time=  10.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=3, min_child_weight=5, n_estimators=200, reg_lambda=5, subsample=0.8; total time=  10.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=3, min_child_weight=5, n_estimators=500, reg_lambda=1, subsample=0.8; total time=  24.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=3, min_child_weight=5, n_estimators=500, reg_lambda=1, subsample=1.0; total time=  24.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=3, min_child_weight=5, n_estimators=500, reg_lambda=5, subsample=1.0; total time=  24.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=200, reg_lambda=1, subsample=1.0; total time=  14.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=200, reg_lambda=5, subsample=1.0; total time=  13.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=500, reg_lambda=1, subsample=1.0; total time=  32.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=500, reg_lambda=5, subsample=0.8; total time=  36.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, min_child_weight=5, n_estimators=200, reg_lambda=1, subsample=0.8; total time=  16.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, min_child_weight=5, n_estimators=200, reg_lambda=1, subsample=1.0; total time=  15.0s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, min_child_weight=5, n_estimators=200, reg_lambda=5, subsample=0.8; total time=  17.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, min_child_weight=5, n_estimators=500, reg_lambda=1, subsample=0.8; total time=  42.0s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, min_child_weight=5, n_estimators=500, reg_lambda=5, subsample=0.8; total time=  45.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.05, max_depth=5, min_child_weight=5, n_estimators=500, reg_lambda=5, subsample=1.0; total time=  35.9s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=200, reg_lambda=5, subsample=0.8; total time=  12.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=500, reg_lambda=1, subsample=0.8; total time=  28.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=500, reg_lambda=1, subsample=1.0; total time=  27.8s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=500, reg_lambda=5, subsample=1.0; total time=  26.8s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=3, min_child_weight=5, n_estimators=200, reg_lambda=1, subsample=1.0; total time=  14.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=3, min_child_weight=5, n_estimators=200, reg_lambda=5, subsample=1.0; total time=  12.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=3, min_child_weight=5, n_estimators=500, reg_lambda=1, subsample=1.0; total time=  29.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=3, min_child_weight=5, n_estimators=500, reg_lambda=5, subsample=0.8; total time=  30.8s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=200, reg_lambda=1, subsample=0.8; total time=  13.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=200, reg_lambda=1, subsample=0.8; total time=  12.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=200, reg_lambda=5, subsample=0.8; total time=  13.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=500, reg_lambda=1, subsample=0.8; total time=  29.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=500, reg_lambda=5, subsample=0.8; total time=  28.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=500, reg_lambda=5, subsample=1.0; total time=  25.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=200, reg_lambda=5, subsample=0.8; total time=  12.0s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=200, reg_lambda=5, subsample=1.0; total time=  11.0s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=500, reg_lambda=1, subsample=1.0; total time=  25.9s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=500, reg_lambda=5, subsample=1.0; total time=  25.4s
# [CV] END colsample_bytree=1.0, learning_rate=0.03, max_depth=3, min_child_weight=1, n_estimators=200, reg_lambda=1, subsample=0.8; total time=  10.0s
# [CV] END colsample_bytree=1.0, learning_rate=0.03, max_depth=3, min_child_weight=1, n_estimators=200, reg_lambda=1, subsample=1.0; total time=   8.8s
# [CV] END colsample_bytree=1.0, learning_rate=0.03, max_depth=3, min_child_weight=1, n_estimators=200, reg_lambda=5, subsample=0.8; total time=   9.7s
# [CV] END colsample_bytree=1.0, learning_rate=0.03, max_depth=3, min_child_weight=1, n_estimators=500, reg_lambda=1, subsample=0.8; total time=  20.5s
# [CV] END colsample_bytree=1.0, learning_rate=0.03, max_depth=3, min_child_weight=1, n_estimators=500, reg_lambda=5, subsample=0.8; total time=  20.4s
# [CV] END colsample_bytree=1.0, learning_rate=0.03, max_depth=3, min_child_weight=1, n_estimators=500, reg_lambda=5, subsample=1.0; total time=  20.3s
# [CV] END colsample_bytree=1.0, learning_rate=0.03, max_depth=3, min_child_weight=5, n_estimators=200, reg_lambda=5, subsample=0.8; total time=  10.0s
# [CV] END colsample_bytree=1.0, learning_rate=0.03, max_depth=3, min_child_weight=5, n_estimators=200, reg_lambda=5, subsample=1.0; total time=   9.6s
# [CV] END colsample_bytree=1.0, learning_rate=0.03, max_depth=3, min_child_weight=5, n_estimators=500, reg_lambda=1, subsample=1.0; total time=  21.4s
# [CV] END colsample_bytree=1.0, learning_rate=0.03, max_depth=3, min_child_weight=5, n_estimators=500, reg_lambda=5, subsample=1.0; total time=  20.9s
# [CV] END colsample_bytree=1.0, learning_rate=0.03, max_depth=5, min_child_weight=1, n_estimators=200, reg_lambda=1, subsample=0.8; total time=  12.2s
# [CV] END colsample_bytree=1.0, learning_rate=0.03, max_depth=5, min_child_weight=1, n_estimators=200, reg_lambda=1, subsample=1.0; total time=  10.3s
# [CV] END colsample_bytree=1.0, learning_rate=0.03, max_depth=5, min_child_weight=1, n_estimators=200, reg_lambda=5, subsample=0.8; total time=  12.7s
# [CV] END colsample_bytree=1.0, learning_rate=0.03, max_depth=5, min_child_weight=1, n_estimators=500, reg_lambda=1, subsample=0.8; total time=  28.3s
# [CV] END colsample_bytree=1.0, learning_rate=0.03, max_depth=5, min_child_weight=1, n_estimators=500, reg_lambda=5, subsample=0.8; total time=  34.3s
# [CV] END colsample_bytree=1.0, learning_rate=0.03, max_depth=5, min_child_weight=1, n_estimators=500, reg_lambda=5, subsample=1.0; total time=  27.4s
# [CV] END colsample_bytree=1.0, learning_rate=0.03, max_depth=5, min_child_weight=5, n_estimators=200, reg_lambda=5, subsample=0.8; total time=  12.8s
# [CV] END colsample_bytree=1.0, learning_rate=0.03, max_depth=5, min_child_weight=5, n_estimators=200, reg_lambda=5, subsample=1.0; total time=  12.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.03, max_depth=5, min_child_weight=5, n_estimators=500, reg_lambda=1, subsample=1.0; total time=  29.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.03, max_depth=5, min_child_weight=5, n_estimators=500, reg_lambda=5, subsample=0.8; total time=  26.3s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=3, min_child_weight=1, n_estimators=200, reg_lambda=1, subsample=0.8; total time=   8.7s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=3, min_child_weight=1, n_estimators=200, reg_lambda=1, subsample=1.0; total time=   6.9s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=3, min_child_weight=1, n_estimators=200, reg_lambda=5, subsample=1.0; total time=   6.5s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=3, min_child_weight=1, n_estimators=500, reg_lambda=1, subsample=0.8; total time=  16.3s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=3, min_child_weight=1, n_estimators=500, reg_lambda=5, subsample=0.8; total time=  15.9s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=3, min_child_weight=1, n_estimators=500, reg_lambda=5, subsample=1.0; total time=  17.3s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=3, min_child_weight=5, n_estimators=200, reg_lambda=5, subsample=0.8; total time=   8.8s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=3, min_child_weight=5, n_estimators=200, reg_lambda=5, subsample=1.0; total time=   8.8s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=3, min_child_weight=5, n_estimators=500, reg_lambda=1, subsample=1.0; total time=  16.9s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=3, min_child_weight=5, n_estimators=500, reg_lambda=5, subsample=1.0; total time=  16.8s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=200, reg_lambda=1, subsample=0.8; total time=   8.8s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=200, reg_lambda=1, subsample=1.0; total time=   8.8s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=200, reg_lambda=5, subsample=1.0; total time=   8.7s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=500, reg_lambda=1, subsample=0.8; total time=  21.8s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=500, reg_lambda=5, subsample=0.8; total time=  22.9s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=5, min_child_weight=5, n_estimators=200, reg_lambda=1, subsample=0.8; total time=  11.9s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=5, min_child_weight=5, n_estimators=200, reg_lambda=1, subsample=1.0; total time=  10.5s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=5, min_child_weight=5, n_estimators=200, reg_lambda=5, subsample=0.8; total time=  10.4s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=5, min_child_weight=5, n_estimators=500, reg_lambda=1, subsample=0.8; total time=  23.7s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=5, min_child_weight=5, n_estimators=500, reg_lambda=1, subsample=1.0; total time=  23.8s
# [CV] END colsample_bytree=1.0, learning_rate=0.05, max_depth=5, min_child_weight=5, n_estimators=500, reg_lambda=5, subsample=1.0; total time=  23.2s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=200, reg_lambda=1, subsample=1.0; total time=   8.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=200, reg_lambda=5, subsample=1.0; total time=  20.0s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=500, reg_lambda=1, subsample=1.0; total time=  23.5s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=500, reg_lambda=5, subsample=0.8; total time=  21.2s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=3, min_child_weight=5, n_estimators=200, reg_lambda=1, subsample=0.8; total time=  20.3s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=3, min_child_weight=5, n_estimators=200, reg_lambda=1, subsample=1.0; total time=  13.5s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=3, min_child_weight=5, n_estimators=200, reg_lambda=5, subsample=1.0; total time=  12.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=3, min_child_weight=5, n_estimators=500, reg_lambda=1, subsample=0.8; total time=  29.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=3, min_child_weight=5, n_estimators=500, reg_lambda=5, subsample=0.8; total time=  18.8s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=3, min_child_weight=5, n_estimators=500, reg_lambda=5, subsample=1.0; total time=  16.8s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=200, reg_lambda=5, subsample=0.8; total time=  10.3s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=200, reg_lambda=5, subsample=1.0; total time=   9.6s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=500, reg_lambda=1, subsample=1.0; total time=  25.1s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=500, reg_lambda=5, subsample=1.0; total time=  23.9s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=200, reg_lambda=1, subsample=0.8; total time=  13.8s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=200, reg_lambda=1, subsample=1.0; total time=  15.5s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=200, reg_lambda=5, subsample=0.8; total time=  15.7s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=500, reg_lambda=1, subsample=0.8; total time=  47.0s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=500, reg_lambda=5, subsample=0.8; total time=  32.9s
# [CV] END colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=500, reg_lambda=5, subsample=1.0; total time=  24.5s

# %%
best_model
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=1.0, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.03, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=5, max_leaves=None,
#              min_child_weight=1, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=200, n_jobs=None,
#              num_parallel_tree=None, random_state=42, ...)

# %%
# Create results dataframe
results_df = test_df.copy()


# Add predictions
results_df['pred_next_close_change_pct'] = (y_test_pred).round(2)

# Impute error
results_df['pred_error'] = results_df['pred_next_close_change_pct'] - results_df['next_close_change_pct']

# Absolute error
results_df['abs_pred_error'] = results_df['pred_error'].abs()

# Directionally correct
results_df['directionally_correct'] = (
    np.sign(results_df['next_close_change_pct']) ==
    np.sign(results_df['pred_next_close_change_pct'])
).astype(int)

# %%
results_df
# Out:
#         timestamp ticker     open      high       low   close     volume  \
# 872    2025-01-02     AA   38.165   39.0400   37.9000   37.99  2703886.0
# 873    2025-01-03     AA   37.950   37.9500   35.3752   35.71  7491799.0
# 874    2025-01-06     AA   36.000   37.0750   35.9200   36.49  5983917.0
# 875    2025-01-07     AA   36.890   37.3000   35.7550   36.24  3381466.0
# 876    2025-01-08     AA   35.780   36.0300   34.7500   36.00  3775303.0
# ...           ...    ...      ...       ...       ...     ...        ...
# 478297 2025-12-24    ZTS  123.100  125.6899  123.0600  125.49  2369020.0
# 478298 2025-12-26    ZTS  125.160  126.3200  124.8000  126.23  3226934.0
# 478299 2025-12-29    ZTS  126.160  126.8500  125.5607  125.98  4465924.0
# 478300 2025-12-30    ZTS  125.550  127.6000  125.4500  126.41  3230541.0
# 478301 2025-12-31    ZTS  126.040  126.8400  125.7700  125.82  2943501.0
#
#             vwap  transactions  close_vs_open_pct  ...  close_lag1  \
# 872      38.3283       33119.0          -0.004585  ...       37.78
# 873      35.9337       63814.0          -0.059025  ...       37.99
# 874      36.4794       58230.0           0.013611  ...       35.71
# 875      36.2093       39434.0          -0.017620  ...       36.49
# 876      35.5672       41012.0           0.006149  ...       36.24
# ...          ...           ...                ...  ...         ...
# 478297  125.1484       29115.0           0.019415  ...      123.54
# 478298  125.8979       45295.0           0.008549  ...      125.49
# 478299  126.0785       51439.0          -0.001427  ...      126.23
# 478300  126.5667       45221.0           0.006850  ...      125.98
# 478301  126.1749       38289.0          -0.001745  ...      126.41
#
#         close_lag2  return_lag1  next_close  next_close_change  \
# 872          37.15     0.016958       35.71              -2.28
# 873          37.78     0.005558       36.49               0.78
# 874          37.99    -0.060016       36.24              -0.25
# 875          35.71     0.021843       36.00              -0.24
# 876          36.49    -0.006851       35.91              -0.09
# ...            ...          ...         ...                ...
# 478297      123.78    -0.001939      126.23               0.74
# 478298      123.54     0.015784      125.98              -0.25
# 478299      125.49     0.005897      126.41               0.43
# 478300      126.23    -0.001981      125.82              -0.59
# 478301      125.98     0.003413      125.92               0.10
#
#         next_close_change_pct  pred_next_close_change_pct  pred_error  \
# 872                 -6.001579                        0.11    6.111579
# 873                  2.184262                        0.05   -2.134262
# 874                 -0.685119                        0.25    0.935119
# 875                 -0.662252                        0.21    0.872252
# 876                 -0.250000                        0.09    0.340000
# ...                       ...                         ...         ...
# 478297               0.589688                       -0.02   -0.609688
# 478298              -0.198051                       -0.01    0.188051
# 478299               0.341324                       -0.02   -0.361324
# 478300              -0.466735                       -0.02    0.446735
# 478301               0.079479                       -0.02   -0.099479
#
#         abs_pred_error  directionally_correct
# 872           6.111579                      0
# 873           2.134262                      1
# 874           0.935119                      0
# 875           0.872252                      0
# 876           0.340000                      0
# ...                ...                    ...
# 478297        0.609688                      0
# 478298        0.188051                      1
# 478299        0.361324                      0
# 478300        0.446735                      1
# 478301        0.099479                      0
#
# [99250 rows x 31 columns]

# %%
# Print evaluation metrics
print("\n===== REGRESSION METRICS =====")

print(f"MAE:    {mae:.4f}")
print(f"MSE:    {mse:.4f}")
print(f"RMSE:   {rmse:.4f}")
print(f"MedAE:  {medae:.4f}")
print(f"R²:     {r2:.4f}")

print(
    f"Percent directionally correct: "
    f"{results_df['directionally_correct'].mean() * 100:.2f}%"
)
# Out:
# ===== REGRESSION METRICS =====
# MAE:    1.9077
# MSE:    10.6053
# RMSE:   3.2566
# MedAE:  1.1877
# R²:     -0.0272
# Percent directionally correct: 48.14%

# %%
results_df.to_csv('models_daily_results/Round2_XGBR_GSMAE.csv', index=False)
