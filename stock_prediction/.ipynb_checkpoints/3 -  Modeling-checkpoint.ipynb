# %% [markdown]
# Modeling

# %% [markdown]
# Suggested I could have up to 100 models.
#
# I will make several variants of each model type. They will vary by GridSearch optimization, feature selection, training slice, and more.
#
# Each model will be saved as a joblib file in a dedicated folder to be loaded later.
#
# The joblib files will be named with parameters, and a table/sheet/dictionary will also be created with more detailed explanations of each.

# %% [markdown]
# Linear Regression,Random Forest Regression, SVM, XGBoost, LSTM, Prophet were specifically named in the instruction. Should also do more.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, r2_score
from sklearn.model_selection import train_test_split
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.metrics import median_absolute_error
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score, KFold

# %% [markdown]
# # This notebook will concern modeling raw daily data with no additional calculated metrics. Additional notebooks will specify the conditions for creating more metrics, choosing sets of features, and modeling.

# %%
df_daily_data = pd.read_csv('transformed_daily_data/dailydata_5years_30ktransacs.csv')
df_daily_data
# Out:
#          timestamp ticker    open     high      low   close        volume  \
# 0       2021-05-05     AA   39.37   40.880   38.640   40.60  7.773673e+06
# 1       2021-05-06     AA   40.89   41.440   39.280   39.89  7.308031e+06
# 2       2021-05-07     AA   39.76   41.380   39.250   41.20  4.909460e+06
# 3       2021-05-10     AA   42.75   44.420   41.020   41.04  1.183422e+07
# 4       2021-05-11     AA   39.07   42.150   38.960   41.32  9.246082e+06
# ...            ...    ...     ...      ...      ...     ...           ...
# 497833  2026-04-27    ZTS  116.62  119.680  116.600  117.87  3.160355e+06
# 497834  2026-04-28    ZTS  117.23  118.290  116.075  116.65  2.972547e+06
# 497835  2026-04-29    ZTS  115.50  115.905  112.970  113.83  3.401808e+06
# 497836  2026-04-30    ZTS  114.04  115.535  113.790  114.97  4.297206e+06
# 497837  2026-05-01    ZTS  116.22  116.250  113.760  114.16  3.203961e+06
#
#             vwap  transactions  avg_daily_transactions  adt_INT
# ...

# %% [markdown]
# # Random Forest
